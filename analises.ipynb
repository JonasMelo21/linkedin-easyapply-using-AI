# %%
import pandas as pd

df = pd.read_csv("dados_vagas_linkedin.csv")
display(df.head())
# Out:
#   data_coleta                titulo                  empresa   local  \
# 0  2026-01-04         Data Engineer             CodeRoad Inc  Brazil
# 1  2026-01-04   Azure Data Engineer                      MSH  Brazil
# 2  2026-01-04         Data Engineer  Pyramid Consulting, Inc  Brazil
# 3  2026-01-04  Senior Data Engineer                   Qubika  Brazil
# 4  2026-01-04         Data Engineer           Insight Global  Brazil
#
#                                             link  \
# 0  https://www.linkedin.com/jobs/view/4345788565
# 1  https://www.linkedin.com/jobs/view/4326001824
# 2  https://www.linkedin.com/jobs/view/4343219413
# 3  https://www.linkedin.com/jobs/view/4342211998
# 4  https://www.linkedin.com/jobs/view/4329818405
#
#                                          senioridade  \
# 0       Pleno/Sênior (Mínimo 4+ anos de experiência)
# 1           Pleno/Sênior (3 a 6 anos de experiência)
# 2  Senior/Especialista (Requer proficiência em 'E...
# ...

# %%
df["titulo"]
# Out:
# 0                                     Data Engineer
# 1                               Azure Data Engineer
# 2                                     Data Engineer
# 3                              Senior Data Engineer
# 4                                     Data Engineer
# 5               Engenheiro(a) de Dados – Databricks
# 6                               Azure Data Engineer
# 7                         Machine Learning Engineer
# 8                         Machine Learning Engineer
# 9                         Machine Learning Engineer
# 10    AI/ML Engineer Specialist - Freelance Project
# 11                                      AI Engineer
# 12                        Machine Learning Engineer
# 13                 Artificial Intelligence Engineer
# 14                            Senior Data Scientist
# 15                                DATA SCIENTIST PL
# 16                            Senior Data Scientist
# 17                                   Data Scientist
# ...

# %%
df.iloc[10]["descricao_raw"]
# Out:
# 'Sobre a vaga\nWhat You’ll Do\n\nDesign and deliver machine learning solutions that combine modern research with practical deployment. Working across industries and use cases, contribute to building robust models that power client-facing tools and internal platforms.\n\nDevelop End-to-End ML Models: Design, train, and evaluate models across supervised, unsupervised, and reinforcement learning domains tailored to diverse problem areas.\nCollaborate on Real-World Solutions: Work with engineers and data scientists to integrate models into deployable systems operating in production environments.\nClient-Focused Problem Solving: Engage with stakeholders to frame ambiguous problems, explore solution paths, and translate technical insights into practical outcomes.\nExplore, Iterate, Validate: Lead the exploration and analysis of datasets using tools like Pandas, NumPy, and Spark to inform model design and performance evaluation.\nResearch-Driven Innovation: Identify opportunities to adapt s
# ...
